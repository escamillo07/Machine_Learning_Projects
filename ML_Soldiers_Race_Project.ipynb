# %% [markdown]
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>

# %% [markdown]
# # WELCOME!

# %% [markdown]
# In this project, you must apply EDA processes for the development of predictive models. Handling outliers, domain knowledge and feature engineering will be challenges.
#
# Also, this project aims to improve your ability to implement algorithms for Multi-Class Classification. Thus, you will have the opportunity to implement many algorithms commonly used for Multi-Class Classification problems.
#
# Before diving into the project, please take a look at the determines and tasks.

# %% [markdown]
# # Determines

# %% [markdown]
# The 2012 US Army Anthropometric Survey (ANSUR II) was executed by the Natick Soldier Research, Development and Engineering Center (NSRDEC) from October 2010 to April 2012 and is comprised of personnel representing the total US Army force to include the US Army Active Duty, Reserves, and National Guard. In addition to the anthropometric and demographic data described below, the ANSUR II database also consists of 3D whole body, foot, and head scans of Soldier participants. These 3D data are not publicly available out of respect for the privacy of ANSUR II participants. The data from this survey are used for a wide range of equipment design, sizing, and tariffing applications within the military and has many potential commercial, industrial, and academic applications.
#
# The ANSUR II working databases contain 93 anthropometric measurements which were directly measured, and 15 demographic/administrative variables explained below. The ANSUR II Male working database contains a total sample of 4,082 subjects. The ANSUR II Female working database contains a total sample of 1,986 subjects.
#
#
# DATA DICT:
# https://data.world/datamil/ansur-ii-data-dictionary/workspace/file?filename=ANSUR+II+Databases+Overview.pdf
#
# ---
#
# To achieve high prediction success, you must understand the data well and develop different approaches that can affect the dependent variable.
#
# Firstly, try to understand the dataset column by column using pandas module. Do research within the scope of domain (body scales, and race characteristics) knowledge on the internet to get to know the data set in the fastest way.
#
# You will implement ***Logistic Regression, Support Vector Machine, XGBoost, Random Forest*** algorithms. Also, evaluate the success of your models with appropriate performance metrics.
#
# At the end of the project, choose the most successful model and try to enhance the scores with ***SMOTE*** make it ready to deploy. Furthermore, use ***SHAP*** to explain how the best model you choose works.

# %% [markdown]
# # Tasks

# %% [markdown]
# #### 1. Exploratory Data Analysis (EDA)
# - Import Libraries, Load Dataset, Exploring Data
#
#     *i. Import Libraries*
#
#     *ii. Ingest Data *
#
#     *iii. Explore Data*
#
#     *iv. Outlier Detection*
#
#     *v.  Drop unnecessary features*
#
# #### 2. Data Preprocessing
# - Scale (if needed)
# - Separete the data frame for evaluation purposes
#
# #### 3. Multi-class Classification
# - Import libraries
# - Implement SVM Classifer
# - Implement Decision Tree Classifier
# - Implement Random Forest Classifer
# - Implement XGBoost Classifer
# - Compare The Models

# %% [markdown]
# # EDA
# - Drop unnecessary colums
# - Drop DODRace class if value count below 500 (we assume that our data model can't learn if it is below 500)

# %% [markdown]
# ## Import Libraries
# Besides Numpy and Pandas, you need to import the necessary modules for data visualization, data preprocessing, Model building and tuning.
#
# *Note: Check out the course materials.*

# %%
#pip install xgboost

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score, cross_validate
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score
from sklearn.metrics import make_scorer
from sklearn.metrics import classification_report,confusion_matrix,plot_confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_curve, auc
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)
pd.set_option('display.width', 1000)

# %%
df_male = pd.read_csv('ANSUR II MALE Public.csv', encoding='latin-1')

# %%
df_female = pd.read_csv('ANSUR II FEMALE Public.csv')

# %% [markdown]
# ## Explore Data (EDA)

# %% [markdown]
# - Drop unnecessary colums
# - Drop DODRace class if value count below 500 (we assume that our data model can't learn if it is below 500)

# %%
df_male.head()
# Out:
#    subjectid  abdominalextensiondepthsitting  acromialheight  acromionradialelength  anklecircumference  axillaheight  balloffootcircumference  balloffootlength  biacromialbreadth  bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  buttockkneelength  buttockpopliteallength  calfcircumference  cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  crotchheight  crotchlengthomphalion  crotchlengthposterioromphalion  earbreadth  earlength  earprotrusion  elbowrestheight  eyeheightsitting  footbreadthhorizontal  footlength  forearmcenterofgriplength  forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  functionalleglength  handbreadth  handcircumference  handlength  headbreadth  headcircumference  headlength  heelanklecircumference  heelbreadth  hipbreadth  hipbreadthsitting  iliocristaleheight  \
# 0      10027                             266            1467                    337                 222          1347                      253               202                401                        369               274               493                  71               319                        291                 142                   979           240            882                619                     509                373             1535           291                1074         259         1292           877                    607                             351          36         71             19              247               802                    101         273                        349                         299                    575                477                 1136           90                214         193          150                583         206                     326           70         332                366                1071
# 1      10032                             233            1395                    326                 220          1293                      245               193                394                        338               257               479                  67               344                        320                 135                   944           232            870                584                     468                357             1471           269                1021         253         1244           851                    615                             376          33         62             18              232               781                     98         263                        348                         289                    523                476                 1096           86                203         195          146                568         201                     334           72         312                356                1046
# 2      10033                             287            1430                    341                 230          1327                      256               196                427                        408               261               544                  75               345                        330                 135                  1054           258            901                623                     506                412             1501           288                1120         267         1288           854                    636                             359          40         61             23              237               810                    103         270                        355                         357                    575                491                 1115           93                220         203          148                573         202                     356           70         349                393                1053
# 3      10092                             234            1347                    310                 230          1239                      262               199                401                        359               262               518                  73               328                        309                 143                   991           242            821                560                     437                395             1423           296                1114         262         1205           769                    590                             341          39         66             25              272               794                    106         267                        352                         318                    593                467                 1034           91                217         194          158                576         199                     341           68         338                367                 986
# 4      10093                             250            1585                    372                 247          1478                      267               224                435                        356               263               524                  80               340                        310                 138                  1029           275           1080                706                     567                425             1684           304                1048         232         1452          1014                    682                             382          32         56             19              188               814                    111         305                        399                         324                    605                550                 1279           94                222         218          153                566         197                     374           69         332                372                1251
#
#    interpupillarybreadth  interscyei  interscyeii  kneeheightmidpatella  kneeheightsitting  lateralfemoralepicondyleheight  lateralmalleolusheight  lowerthighcircumference  mentonsellionlength  neckcircumference  neckcircumferencebase  overheadfingertipreachsitting  palmlength  poplitealheight  radialestylionlength  shouldercircumference  shoulderelbowlength  shoulderlength  sittingheight  sleevelengthspinewrist  sleeveoutseam  span  stature  suprasternaleheight  tenthribheight  thighcircumference  thighclearance  thumbtipreach  tibialheight  tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  waistbacklength  waistbreadth  waistcircumference  waistdepth  waistfrontlengthsitting  waistheightomphalion  weightkg  wristcircumference  wristheight Gender       Date Installation     Component                  Branch PrimaryMOS SubjectsBirthLocation  SubjectNumericRace Ethnicity  DODRace  Age  Heightin  Weightlbs WritingPreference
# 0                    685         422          441                   502                560                             500                      77                      391                  118                400                    436                           1447         113              437                   273                   1151                  368             145            928                     883            600  1782     1776                 1449            1092                 610             164            786           491               140                  919                           1700              501           329                 933         240                      440                  1054       815                 175          853   Male   4-Oct-10    Fort Hood  Regular Army             Combat Arms        19D          North Dakota                   1       NaN        1   41        71        180        Right hand
# 1                    620         441          447                   490                540                             488                      73                      371                  131                380                    420                           1380         118              417                   254                   1119                  353             141            884                     868            564  1745     1702                 1387            1076                 572             169            822           476               120                  918                           1627              432           316                 870         225                      371                  1054       726                 167          815   Male   4-Oct-10    Fort Hood  Regular Army          Combat Support        68W              New York                   1       NaN        1   35        68        160         Left hand
# 2                    665         462          475                   496                556                             482                      72                      409                  123                403                    434                           1447         121              431                   268                   1276                  367             167            917                     910            604  1867     1735                 1438            1105                 685             198            807           477               125                  918                           1678              472           329                 964         255                      411                  1041       929                 180          831   Male   4-Oct-10    Fort Hood  Regular Army          Combat Support        68W              New York                   2       NaN        2   42        68        205         Left hand
# 3                    640         458          461                   460                511                             452                      76                      393                  106                407                    446                           1357         118              393                   249                   1155                  330             148            903                     848            550  1708     1655                 1346            1021                 604             180            803           445               127                  847                           1625              461           315                 857         205                      399                   968       794                 176          793   Male  12-Oct-10    Fort Hood  Regular Army  Combat Service Support        88M             Wisconsin                   1       NaN        1   31        66        175        Right hand
# 4                    675         481          505                   612                666                             585                      85                      458                  135                398                    430                           1572         132              523                   302                   1231                  400             180            919                     995            641  2035     1914                 1596            1292                 672             194            962           584               122                 1090                           1679              467           303                 868         214                      379                  1245       946                 188          954   Male  12-Oct-10    Fort Hood  Regular Army  Combat Service Support        92G        North Carolina                   2       NaN        2   21        77        213        Right hand

# %%
df_male.columns
# Out:
# Index(['subjectid', 'abdominalextensiondepthsitting', 'acromialheight', 'acromionradialelength', 'anklecircumference', 'axillaheight', 'balloffootcircumference', 'balloffootlength', 'biacromialbreadth', 'bicepscircumferenceflexed',
#        ...
#        'Branch', 'PrimaryMOS', 'SubjectsBirthLocation', 'SubjectNumericRace', 'Ethnicity', 'DODRace', 'Age', 'Heightin', 'Weightlbs', 'WritingPreference'], dtype='object', length=108)

# %%
df_female.head()
# Out:
#    SubjectId  abdominalextensiondepthsitting  acromialheight  acromionradialelength  anklecircumference  axillaheight  balloffootcircumference  balloffootlength  biacromialbreadth  bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  buttockkneelength  buttockpopliteallength  calfcircumference  cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  crotchheight  crotchlengthomphalion  crotchlengthposterioromphalion  earbreadth  earlength  earprotrusion  elbowrestheight  eyeheightsitting  footbreadthhorizontal  footlength  forearmcenterofgriplength  forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  functionalleglength  handbreadth  handcircumference  handlength  headbreadth  headcircumference  headlength  heelanklecircumference  heelbreadth  hipbreadth  hipbreadthsitting  iliocristaleheight  \
# 0      10037                             231            1282                    301                 204          1180                      222               177                373                        315               263               466                  65               338                        301                 141                  1011           223            836                587                     476                360             1336           274                 922         245         1095           759                    557                             310          35         65             16              220               713                     91         246                        316                         265                    517                432                 1028           75                182         184          141                548         191                     314           69         345                388                 966
# 1      10038                             194            1379                    320                 207          1292                      225               178                372                        272               250               430                  64               294                        270                 126                   893           186            900                583                     483                350             1440           261                 839         206         1234           835                    549                             329          32         60             23              208               726                     91         249                        341                         247                    468                463                 1117           78                187         189          138                535         180                     307           60         315                335                1048
# 2      10042                             183            1369                    329                 233          1271                      237               196                397                        300               276               450                  69               309                        270                 128                   987           204            861                583                     466                384             1451           287                 874         223         1226           821                    643                             374          36         65             26              204               790                    100         265                        343                         262                    488                469                 1060           84                198         195          146                588         207                     331           70         356                399                1043
# 3      10043                             261            1356                    306                 214          1250                      240               188                384                        364               276               484                  68               340                        294                 144                  1012           253            897                599                     471                372             1430           269                1008         285         1170           804                    640                             351          38         62             22              244               775                     97         265                        331                         309                    529                455                 1069           80                192         186          153                593         206                     332           68         337                402                1029
# 4      10051                             309            1303                    308                 214          1210                      217               182                378                        320               336               525                  67               300                        295                 135                  1281           284            811                607                     467                433             1362           305                1089         290         1112           726                    686                             356          34         65             18              233               732                     88         247                        339                         260                    596                447                 1039           78                183         187          140                522         181                     308           63         448                499                 964
#
#    interpupillarybreadth  interscyei  interscyeii  kneeheightmidpatella  kneeheightsitting  lateralfemoralepicondyleheight  lateralmalleolusheight  lowerthighcircumference  mentonsellionlength  neckcircumference  neckcircumferencebase  overheadfingertipreachsitting  palmlength  poplitealheight  radialestylionlength  shouldercircumference  shoulderelbowlength  shoulderlength  sittingheight  sleevelengthspinewrist  sleeveoutseam  span  stature  suprasternaleheight  tenthribheight  thighcircumference  thighclearance  thumbtipreach  tibialheight  tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  waistbacklength  waistbreadth  waistcircumference  waistdepth  waistfrontlengthsitting  waistheightomphalion  weightkg  wristcircumference  wristheight  Gender      Date Installation     Component                  Branch PrimaryMOS SubjectsBirthLocation  SubjectNumericRace           Ethnicity  DODRace  Age  Heightin  Weightlbs WritingPreference
# 0                    645         363          399                   435                496                             447                      55                      404                  118                335                    368                           1268         113              362                   235                   1062                  327             148            803                     809            513  1647     1560                 1280            1013                 622             174            736           430               110                  844                           1488              406           295                 850         217                      345                   942       657                 152          756  Female  5-Oct-10    Fort Hood  Regular Army          Combat Support        92Y               Germany                   2                 NaN        2   26        61        142        Right hand
# 1                    595         340          375                   483                532                             492                      69                      334                  115                302                    345                           1389         110              426                   259                   1014                  346             142            835                     810            575  1751     1665                 1372            1107                 524             152            771           475               125                  901                           1470              422           254                 708         168                      329                  1032       534                 155          815  Female  5-Oct-10    Fort Hood  Regular Army  Combat Service Support        25U            California                   3             Mexican        3   21        64        120        Right hand
# 2                    655         345          399                   470                530                             469                      64                      401                  135                325                    369                           1414         122              398                   258                   1049                  362             164            904                     855            568  1779     1711                 1383            1089                 577             164            814           458               129                  882                           1542              419           269                 727         159                      367                  1035       663                 162          799  Female  5-Oct-10    Fort Hood  Regular Army  Combat Service Support        35D                 Texas                   1                 NaN        1   23        68        147        Right hand
# 3                    655         392          435                   469                520                             478                      67                      402                  118                357                    386                           1329         115              394                   250                   1121                  333             157            875                     815            536  1708     1660                 1358            1065                 679             187            736           463               125                  866                           1627              451           302                 923         235                      371                   999       782                 173          818  Female  5-Oct-10    Fort Hood  Regular Army  Combat Service Support        25U  District of Columbia                   8  Caribbean Islander        2   22        66        175        Right hand
# 4                    635         428          435                   440                491                             441                      63                      479                  114                340                    358                           1350         116              345                   242                   1151                  329             156            824                     810            559  1702     1572                 1292            1030                 766             197            766           429               116                  800                           1698              452           405                1163         300                      380                   911       886                 152          762  Female  5-Oct-10    Fort Hood  Regular Army             Combat Arms        42A                 Texas                   1                 NaN        1   45        63        195        Right hand

# %%
df_female.columns
# Out:
# Index(['SubjectId', 'abdominalextensiondepthsitting', 'acromialheight', 'acromionradialelength', 'anklecircumference', 'axillaheight', 'balloffootcircumference', 'balloffootlength', 'biacromialbreadth', 'bicepscircumferenceflexed',
#        ...
#        'Branch', 'PrimaryMOS', 'SubjectsBirthLocation', 'SubjectNumericRace', 'Ethnicity', 'DODRace', 'Age', 'Heightin', 'Weightlbs', 'WritingPreference'], dtype='object', length=108)

# %%
df_female.rename(columns={"SubjectId": "subjectid"}, inplace=True)

# %%
print(df_male.shape)
print(df_female.shape)
# Out:
# (4082, 108)
# (1986, 108)

# %%
df = pd.concat([df_male,df_female], axis=0, ignore_index=True)
df.head()
# Out:
#    subjectid  abdominalextensiondepthsitting  acromialheight  acromionradialelength  anklecircumference  axillaheight  balloffootcircumference  balloffootlength  biacromialbreadth  bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  buttockkneelength  buttockpopliteallength  calfcircumference  cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  crotchheight  crotchlengthomphalion  crotchlengthposterioromphalion  earbreadth  earlength  earprotrusion  elbowrestheight  eyeheightsitting  footbreadthhorizontal  footlength  forearmcenterofgriplength  forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  functionalleglength  handbreadth  handcircumference  handlength  headbreadth  headcircumference  headlength  heelanklecircumference  heelbreadth  hipbreadth  hipbreadthsitting  iliocristaleheight  \
# 0      10027                             266            1467                    337                 222          1347                      253               202                401                        369               274               493                  71               319                        291                 142                   979           240            882                619                     509                373             1535           291                1074         259         1292           877                    607                             351          36         71             19              247               802                    101         273                        349                         299                    575                477                 1136           90                214         193          150                583         206                     326           70         332                366                1071
# 1      10032                             233            1395                    326                 220          1293                      245               193                394                        338               257               479                  67               344                        320                 135                   944           232            870                584                     468                357             1471           269                1021         253         1244           851                    615                             376          33         62             18              232               781                     98         263                        348                         289                    523                476                 1096           86                203         195          146                568         201                     334           72         312                356                1046
# 2      10033                             287            1430                    341                 230          1327                      256               196                427                        408               261               544                  75               345                        330                 135                  1054           258            901                623                     506                412             1501           288                1120         267         1288           854                    636                             359          40         61             23              237               810                    103         270                        355                         357                    575                491                 1115           93                220         203          148                573         202                     356           70         349                393                1053
# 3      10092                             234            1347                    310                 230          1239                      262               199                401                        359               262               518                  73               328                        309                 143                   991           242            821                560                     437                395             1423           296                1114         262         1205           769                    590                             341          39         66             25              272               794                    106         267                        352                         318                    593                467                 1034           91                217         194          158                576         199                     341           68         338                367                 986
# 4      10093                             250            1585                    372                 247          1478                      267               224                435                        356               263               524                  80               340                        310                 138                  1029           275           1080                706                     567                425             1684           304                1048         232         1452          1014                    682                             382          32         56             19              188               814                    111         305                        399                         324                    605                550                 1279           94                222         218          153                566         197                     374           69         332                372                1251
#
#    interpupillarybreadth  interscyei  interscyeii  kneeheightmidpatella  kneeheightsitting  lateralfemoralepicondyleheight  lateralmalleolusheight  lowerthighcircumference  mentonsellionlength  neckcircumference  neckcircumferencebase  overheadfingertipreachsitting  palmlength  poplitealheight  radialestylionlength  shouldercircumference  shoulderelbowlength  shoulderlength  sittingheight  sleevelengthspinewrist  sleeveoutseam  span  stature  suprasternaleheight  tenthribheight  thighcircumference  thighclearance  thumbtipreach  tibialheight  tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  waistbacklength  waistbreadth  waistcircumference  waistdepth  waistfrontlengthsitting  waistheightomphalion  weightkg  wristcircumference  wristheight Gender       Date Installation     Component                  Branch PrimaryMOS SubjectsBirthLocation  SubjectNumericRace Ethnicity  DODRace  Age  Heightin  Weightlbs WritingPreference
# 0                    685         422          441                   502                560                             500                      77                      391                  118                400                    436                           1447         113              437                   273                   1151                  368             145            928                     883            600  1782     1776                 1449            1092                 610             164            786           491               140                  919                           1700              501           329                 933         240                      440                  1054       815                 175          853   Male   4-Oct-10    Fort Hood  Regular Army             Combat Arms        19D          North Dakota                   1       NaN        1   41        71        180        Right hand
# 1                    620         441          447                   490                540                             488                      73                      371                  131                380                    420                           1380         118              417                   254                   1119                  353             141            884                     868            564  1745     1702                 1387            1076                 572             169            822           476               120                  918                           1627              432           316                 870         225                      371                  1054       726                 167          815   Male   4-Oct-10    Fort Hood  Regular Army          Combat Support        68W              New York                   1       NaN        1   35        68        160         Left hand
# 2                    665         462          475                   496                556                             482                      72                      409                  123                403                    434                           1447         121              431                   268                   1276                  367             167            917                     910            604  1867     1735                 1438            1105                 685             198            807           477               125                  918                           1678              472           329                 964         255                      411                  1041       929                 180          831   Male   4-Oct-10    Fort Hood  Regular Army          Combat Support        68W              New York                   2       NaN        2   42        68        205         Left hand
# 3                    640         458          461                   460                511                             452                      76                      393                  106                407                    446                           1357         118              393                   249                   1155                  330             148            903                     848            550  1708     1655                 1346            1021                 604             180            803           445               127                  847                           1625              461           315                 857         205                      399                   968       794                 176          793   Male  12-Oct-10    Fort Hood  Regular Army  Combat Service Support        88M             Wisconsin                   1       NaN        1   31        66        175        Right hand
# 4                    675         481          505                   612                666                             585                      85                      458                  135                398                    430                           1572         132              523                   302                   1231                  400             180            919                     995            641  2035     1914                 1596            1292                 672             194            962           584               122                 1090                           1679              467           303                 868         214                      379                  1245       946                 188          954   Male  12-Oct-10    Fort Hood  Regular Army  Combat Service Support        92G        North Carolina                   2       NaN        2   21        77        213        Right hand

# %%
df.shape
# Out:
# (6068, 108)

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6068 entries, 0 to 6067
# Data columns (total 108 columns):
#  #    Column                          Dtype
# ---   ------                          -----
#  0    subjectid                       int64
#  1    abdominalextensiondepthsitting  int64
#  2    acromialheight                  int64
#  3    acromionradialelength           int64
#  4    anklecircumference              int64
#  5    axillaheight                    int64
#  6    balloffootcircumference         int64
#  7    balloffootlength                int64
#  8    biacromialbreadth               int64
#  9    bicepscircumferenceflexed       int64
#  10   bicristalbreadth                int64
#  11   bideltoidbreadth                int64
#  12   bimalleolarbreadth              int64
#  13   bitragionchinarc                int64
#  14   bitragionsubmandibulararc       int64
#  15   bizygomaticbreadth              int64
#  16   buttockcircumference            int64
#  17   buttockdepth                    int64
#  18   buttockheight                   int64
#  19   buttockkneelength               int64
#  20   buttockpopliteallength          int64
#  21   calfcircumference               int64
#  22   cervicaleheight                 int64
#  23   chestbreadth                    int64
#  24   chestcircumference              int64
#  25   chestdepth                      int64
#  26   chestheight                     int64
#  27   crotchheight                    int64
#  28   crotchlengthomphalion           int64
#  29   crotchlengthposterioromphalion  int64
#  30   earbreadth                      int64
#  31   earlength                       int64
#  32   earprotrusion                   int64
#  33   elbowrestheight                 int64
#  34   eyeheightsitting                int64
#  35   footbreadthhorizontal           int64
#  36   footlength                      int64
#  37   forearmcenterofgriplength       int64
#  38   forearmcircumferenceflexed      int64
#  39   forearmforearmbreadth           int64
#  40   forearmhandlength               int64
#  41   functionalleglength             int64
#  42   handbreadth                     int64
#  43   handcircumference               int64
#  44   handlength                      int64
#  45   headbreadth                     int64
#  46   headcircumference               int64
#  47   headlength                      int64
#  48   heelanklecircumference          int64
#  49   heelbreadth                     int64
#  50   hipbreadth                      int64
#  51   hipbreadthsitting               int64
#  52   iliocristaleheight              int64
#  53   interpupillarybreadth           int64
#  54   interscyei                      int64
#  55   interscyeii                     int64
#  56   kneeheightmidpatella            int64
#  57   kneeheightsitting               int64
#  58   lateralfemoralepicondyleheight  int64
#  59   lateralmalleolusheight          int64
#  60   lowerthighcircumference         int64
#  61   mentonsellionlength             int64
#  62   neckcircumference               int64
#  63   neckcircumferencebase           int64
#  64   overheadfingertipreachsitting   int64
#  65   palmlength                      int64
#  66   poplitealheight                 int64
#  67   radialestylionlength            int64
#  68   shouldercircumference           int64
#  69   shoulderelbowlength             int64
#  70   shoulderlength                  int64
#  71   sittingheight                   int64
#  72   sleevelengthspinewrist          int64
#  73   sleeveoutseam                   int64
#  74   span                            int64
#  75   stature                         int64
#  76   suprasternaleheight             int64
#  77   tenthribheight                  int64
#  78   thighcircumference              int64
#  79   thighclearance                  int64
#  80   thumbtipreach                   int64
#  81   tibialheight                    int64
#  82   tragiontopofhead                int64
#  83   trochanterionheight             int64
#  84   verticaltrunkcircumferenceusa   int64
#  85   waistbacklength                 int64
#  86   waistbreadth                    int64
#  87   waistcircumference              int64
#  88   waistdepth                      int64
#  89   waistfrontlengthsitting         int64
#  90   waistheightomphalion            int64
#  91   weightkg                        int64
#  92   wristcircumference              int64
#  93   wristheight                     int64
#  94   Gender                          object
#  95   Date                            object
#  96   Installation                    object
#  97   Component                       object
#  98   Branch                          object
#  99   PrimaryMOS                      object
#  100  SubjectsBirthLocation           object
#  101  SubjectNumericRace              int64
#  102  Ethnicity                       object
#  103  DODRace                         int64
#  104  Age                             int64
#  105  Heightin                        int64
#  106  Weightlbs                       int64
#  107  WritingPreference               object
# dtypes: int64(99), object(9)
# memory usage: 5.0+ MB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.select_dtypes("O")
# Out:
#       Gender       Date Installation            Component                  Branch PrimaryMOS SubjectsBirthLocation Ethnicity WritingPreference
# 0       Male   4-Oct-10    Fort Hood         Regular Army             Combat Arms        19D          North Dakota       NaN        Right hand
# 1       Male   4-Oct-10    Fort Hood         Regular Army          Combat Support        68W              New York       NaN         Left hand
# 2       Male   4-Oct-10    Fort Hood         Regular Army          Combat Support        68W              New York       NaN         Left hand
# 3       Male  12-Oct-10    Fort Hood         Regular Army  Combat Service Support        88M             Wisconsin       NaN        Right hand
# 4       Male  12-Oct-10    Fort Hood         Regular Army  Combat Service Support        92G        North Carolina       NaN        Right hand
# ...      ...        ...          ...                  ...                     ...        ...                   ...       ...               ...
# 6063  Female   5-Apr-12  Camp Shelby  Army National Guard          Combat Support        42A                 Texas   Mexican        Right hand
# 6064  Female   5-Apr-12  Camp Shelby  Army National Guard          Combat Support        25U                 Texas   Mexican        Right hand
# 6065  Female   5-Apr-12  Camp Shelby  Army National Guard          Combat Support        42A                 Texas       NaN        Right hand
# 6066  Female   5-Apr-12  Camp Shelby  Army National Guard          Combat Support        92Y                 Texas   Mexican        Right hand
# 6067  Female  28-May-11   Fort McCoy  Army National Guard          Combat Support        92F                 Texas   Mexican        Right hand
#
# [6068 rows x 9 columns]

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Ethnicity                         4647
# subjectid                            0
# radialestylionlength                 0
# thighcircumference                   0
# tenthribheight                       0
# suprasternaleheight                  0
# stature                              0
# span                                 0
# sleeveoutseam                        0
# sleevelengthspinewrist               0
# sittingheight                        0
# shoulderlength                       0
# shoulderelbowlength                  0
# shouldercircumference                0
# poplitealheight                      0
# thumbtipreach                        0
# palmlength                           0
# overheadfingertipreachsitting        0
# neckcircumferencebase                0
# neckcircumference                    0
# mentonsellionlength                  0
# lowerthighcircumference              0
# lateralmalleolusheight               0
# lateralfemoralepicondyleheight       0
# kneeheightsitting                    0
# kneeheightmidpatella                 0
# thighclearance                       0
# tibialheight                         0
# abdominalextensiondepthsitting       0
# tragiontopofhead                     0
# Weightlbs                            0
# Heightin                             0
# Age                                  0
# DODRace                              0
# SubjectNumericRace                   0
# SubjectsBirthLocation                0
# PrimaryMOS                           0
# Branch                               0
# Component                            0
# Installation                         0
# Date                                 0
# Gender                               0
# wristheight                          0
# wristcircumference                   0
# weightkg                             0
# waistheightomphalion                 0
# waistfrontlengthsitting              0
# waistdepth                           0
# waistcircumference                   0
# waistbreadth                         0
# waistbacklength                      0
# verticaltrunkcircumferenceusa        0
# trochanterionheight                  0
# interscyeii                          0
# interscyei                           0
# interpupillarybreadth                0
# chestheight                          0
# chestcircumference                   0
# chestbreadth                         0
# cervicaleheight                      0
# calfcircumference                    0
# buttockpopliteallength               0
# buttockkneelength                    0
# buttockheight                        0
# buttockdepth                         0
# buttockcircumference                 0
# bizygomaticbreadth                   0
# bitragionsubmandibulararc            0
# bitragionchinarc                     0
# bimalleolarbreadth                   0
# bideltoidbreadth                     0
# bicristalbreadth                     0
# bicepscircumferenceflexed            0
# biacromialbreadth                    0
# balloffootlength                     0
# balloffootcircumference              0
# axillaheight                         0
# anklecircumference                   0
# acromionradialelength                0
# acromialheight                       0
# chestdepth                           0
# crotchheight                         0
# iliocristaleheight                   0
# crotchlengthomphalion                0
# hipbreadthsitting                    0
# hipbreadth                           0
# heelbreadth                          0
# heelanklecircumference               0
# headlength                           0
# headcircumference                    0
# headbreadth                          0
# handlength                           0
# handcircumference                    0
# handbreadth                          0
# functionalleglength                  0
# forearmhandlength                    0
# forearmforearmbreadth                0
# forearmcircumferenceflexed           0
# forearmcenterofgriplength            0
# footlength                           0
# footbreadthhorizontal                0
# eyeheightsitting                     0
# elbowrestheight                      0
# earprotrusion                        0
# earlength                            0
# earbreadth                           0
# crotchlengthposterioromphalion       0
# WritingPreference                    0
# dtype: int64

# %%
print(df["DODRace"].value_counts())
df["DODRace"].value_counts().plot(kind="pie", autopct='%1.1f%%',figsize=(10,10));
# Out:
# 1    3792
# 2    1298
# 3     679
# 4     188
# 6      59
# 5      49
# 8       3
# Name: DODRace, dtype: int64

# %%
[col for col in df.columns if df[col].isnull().any()]
# Out:
# ['Ethnicity']

# %%
df['Ethnicity'].isnull().sum()
# Out:
# 4647

# %%
df.drop('Ethnicity', axis=1, inplace=True)

# %%
df.describe(include=['O'])
# Out:
#        Gender       Date Installation     Component                  Branch PrimaryMOS SubjectsBirthLocation WritingPreference
# count    6068       6068         6068          6068                    6068       6068                  6068              6068
# unique      2        253           12             3                       3        285                   152                 3
# top      Male  27-Feb-12  Camp Shelby  Regular Army  Combat Service Support        11B            California        Right hand
# freq     4082         45         1160          3140                    3174        671                   446              5350

# %%
print(df["DODRace"].value_counts())
# Out:
# 1    3792
# 2    1298
# 3     679
# 4     188
# 6      59
# 5      49
# 8       3
# Name: DODRace, dtype: int64

# %%
df.DODRace.unique()
# Out:
# array([1, 2, 3, 4, 5, 6, 8], dtype=int64)

# %%
df["DODRace"] = df.DODRace.map({
                                    1: "White",
                                    2: "Black",
                                    3: "Hispanic",
                                    4: "Asian",
                                    5: "Native American",
                                    6: "Pacific Islander",
                                    8: "Other"
                                  })

# %%
plt.figure(figsize=(8,4))
ax = sns.countplot(df['DODRace'])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() + 0.3, p.get_height() * 1.03));

# %%
df.Component.value_counts()
# Out:
# Regular Army           3140
# Army National Guard    2708
# Army Reserve            220
# Name: Component, dtype: int64

# %%
df.groupby(["Component"])["DODRace"].value_counts()
# Out:
# Component            DODRace
# Army National Guard  White               1855
#                      Black                499
#                      Hispanic             253
#                      Asian                 60
#                      Native American       24
#                      Pacific Islander      17
# Army Reserve         White                114
#                      Black                 52
#                      Hispanic              41
#                      Asian                  9
#                      Pacific Islander       3
#                      Native American        1
# Regular Army         White               1823
#                      Black                747
#                      Hispanic             385
#                      Asian                119
#                      Pacific Islander      39
#                      Native American       24
#                      Other                  3
# Name: DODRace, dtype: int64

# %%
df.groupby(["Component", "Branch"])["DODRace"].value_counts()
# Out:
# Component            Branch                  DODRace
# Army National Guard  Combat Arms             White               623
#                                              Black                79
#                                              Hispanic             74
#                                              Asian                18
#                                              Native American       9
#                                              Pacific Islander      4
#                      Combat Service Support  White               917
#                                              Black               312
#                                              Hispanic            142
#                                              Asian                33
#                                              Pacific Islander     11
#                                              Native American      10
#                      Combat Support          White               315
#                                              Black               108
#                                              Hispanic             37
#                                              Asian                 9
#                                              Native American       5
#                                              Pacific Islander      2
# Army Reserve         Combat Arms             White                 5
#                                              Hispanic              1
#                      Combat Service Support  White                82
#                                              Hispanic             30
#                                              Black                24
#                                              Asian                 7
#                                              Pacific Islander      2
#                                              Native American       1
#                      Combat Support          Black                28
#                                              White                27
#                                              Hispanic             10
#                                              Asian                 2
#                                              Pacific Islander      1
# Regular Army         Combat Arms             White               518
#                                              Hispanic            114
#                                              Black                94
#                                              Asian                26
#                                              Pacific Islander      9
#                                              Native American       7
#                                              Other                 1
#                      Combat Service Support  White               912
#                                              Black               409
#                                              Hispanic            193
#                                              Asian                59
#                                              Native American      14
#                                              Pacific Islander     14
#                                              Other                 2
#                      Combat Support          White               393
#                                              Black               244
#                                              Hispanic             78
#                                              Asian                34
#                                              Pacific Islander     16
#                                              Native American       3
# Name: DODRace, dtype: int64

# %%
df.groupby(["Weightlbs"])["DODRace"].value_counts()
# Out:
# Weightlbs  DODRace
# 0          Hispanic              1
# 86         White                 1
# 88         White                 1
# 90         Black                 1
# 95         Black                 1
#            Hispanic              1
#            White                 1
# 96         White                 1
# 98         Hispanic              1
# 100        Black                 3
#            Asian                 2
#            White                 2
# 101        White                 1
# 102        White                 2
#            Asian                 1
#            Native American       1
# 103        White                 3
#            Black                 2
#            Hispanic              1
#            Pacific Islander      1
# 104        Hispanic              2
# 105        White                 5
#            Hispanic              2
#            Asian                 1
#            Black                 1
#            Pacific Islander      1
# 106        Black                 2
#            Pacific Islander      1
#            White                 1
# 107        White                 2
# 108        Black                 2
#            Hispanic              2
#            Asian                 1
#            Pacific Islander      1
#            White                 1
# 109        White                 2
#            Hispanic              1
# 110        White                17
#            Asian                 5
#            Black                 3
# 111        Hispanic              2
#            Black                 1
#            White                 1
# 112        White                 5
#            Asian                 1
#            Black                 1
# 113        Asian                 1
#            Black                 1
#            Hispanic              1
#            White                 1
# 114        White                 4
#            Black                 3
#            Hispanic              1
# 115        White                14
#            Black                 6
#            Asian                 4
#            Hispanic              1
#            Pacific Islander      1
# 116        Black                 9
#            White                 4
#            Hispanic              3
# 117        White                 6
#            Black                 2
# 118        Black                 8
#            White                 8
#            Asian                 2
#            Hispanic              2
# 119        Black                 2
#            Hispanic              2
#            White                 2
#            Asian                 1
# 120        White                31
#            Black                11
#            Hispanic              7
#            Asian                 3
#            Native American       1
# 121        White                 3
#            Black                 2
# 122        White                 6
#            Black                 3
#            Hispanic              3
#            Asian                 2
# 123        White                 5
#            Black                 4
#            Hispanic              3
#            Pacific Islander      1
# 124        White                10
#            Black                 4
#            Hispanic              4
#            Asian                 2
#            Pacific Islander      1
# 125        White                32
#            Black                13
#            Hispanic              8
#            Asian                 4
#            Native American       1
#            Pacific Islander      1
# 126        White                11
#            Asian                 4
#            Black                 3
# 127        White                18
#            Hispanic              8
#            Black                 7
#            Asian                 2
#            Pacific Islander      2
# 128        White                20
#            Black                 9
#            Hispanic              5
#            Pacific Islander      3
#            Asian                 2
# 129        Black                 5
#            White                 4
#            Hispanic              2
#            Asian                 1
# 130        White                64
#            Black                21
#            Hispanic             15
#            Asian                 5
#            Pacific Islander      2
# 131        White                 5
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() + 0.3, p.get_height() * 1.03));

# %%
plt.figure(figsize=(20,8))
ax = sns.countplot(df['SubjectsBirthLocation'])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
# for p in ax.patches:
#     ax.annotate(str(p.get_height()), (p.get_x() + 0.3, p.get_height() * 1.03))
plt.xticks(rotation=45);

# %%
plt.figure(figsize=(8,4))
ax = sns.countplot(df['Branch'])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() + 0.3, p.get_height() * 1.03));

# %%
plt.figure(figsize=(8,4))
ax = sns.countplot(df["Installation"])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() + 0.3, p.get_height() * 1.03))
    plt.xticks(rotation=45);

# %%
plt.figure(figsize=(8,4))
ax = sns.countplot(df["Component"])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() + 0.3, p.get_height() * 1.03));

# %%
drop_list1 = [
    "Date", "Installation", "Component", "Branch", "PrimaryMOS",
    "Weightlbs", "Heightin",   
]

# %%
df.SubjectNumericRace.value_counts()
# Out:
# 1        3561
# 2        1026
# 3         541
# 31        160
# 51        126
# 8         116
# 4         109
# 21         60
# 6          59
# 41         46
# 61         35
# 23         34
# 28         26
# 251        20
# 5          18
# 18         18
# 25         14
# 351        10
# 38          9
# 64          8
# 62          8
# 35          8
# 42          7
# 63          7
# 231         6
# 43          5
# 235         4
# 218         3
# 651         2
# 2351        2
# 318         2
# 641         2
# 451         2
# 423         2
# 431         2
# 2518        2
# 48          1
# 631         1
# 4251        1
# 428         1
# 238         1
# 358         1
# 425         1
# 42351       1
# Name: SubjectNumericRace, dtype: int64

# %%
df.drop("SubjectNumericRace",axis=1,inplace=True)

# %%
df.DODRace.value_counts()
# Out:
# White               3792
# Black               1298
# Hispanic             679
# Asian                188
# Pacific Islander      59
# Native American       49
# Other                  3
# Name: DODRace, dtype: int64

# %%
df = df[(df["DODRace"] == "White") | (df["DODRace"] == "Black") |
                (df["DODRace"] == "Hispanic")]
# 500 den aşağısını atacaktık

# %%
df
# Out:
#       subjectid  abdominalextensiondepthsitting  acromialheight  acromionradialelength  anklecircumference  axillaheight  balloffootcircumference  balloffootlength  biacromialbreadth  bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  buttockkneelength  buttockpopliteallength  calfcircumference  cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  crotchheight  crotchlengthomphalion  crotchlengthposterioromphalion  earbreadth  earlength  earprotrusion  elbowrestheight  eyeheightsitting  footbreadthhorizontal  footlength  forearmcenterofgriplength  forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  functionalleglength  handbreadth  handcircumference  handlength  headbreadth  headcircumference  headlength  heelanklecircumference  heelbreadth  hipbreadth  hipbreadthsitting  iliocristaleheight  \
# 0         10027                             266            1467                    337                 222          1347                      253               202                401                        369               274               493                  71               319                        291                 142                   979           240            882                619                     509                373             1535           291                1074         259         1292           877                    607                             351          36         71             19              247               802                    101         273                        349                         299                    575                477                 1136           90                214         193          150                583         206                     326           70         332                366                1071
# 1         10032                             233            1395                    326                 220          1293                      245               193                394                        338               257               479                  67               344                        320                 135                   944           232            870                584                     468                357             1471           269                1021         253         1244           851                    615                             376          33         62             18              232               781                     98         263                        348                         289                    523                476                 1096           86                203         195          146                568         201                     334           72         312                356                1046
# 2         10033                             287            1430                    341                 230          1327                      256               196                427                        408               261               544                  75               345                        330                 135                  1054           258            901                623                     506                412             1501           288                1120         267         1288           854                    636                             359          40         61             23              237               810                    103         270                        355                         357                    575                491                 1115           93                220         203          148                573         202                     356           70         349                393                1053
# 3         10092                             234            1347                    310                 230          1239                      262               199                401                        359               262               518                  73               328                        309                 143                   991           242            821                560                     437                395             1423           296                1114         262         1205           769                    590                             341          39         66             25              272               794                    106         267                        352                         318                    593                467                 1034           91                217         194          158                576         199                     341           68         338                367                 986
# 4         10093                             250            1585                    372                 247          1478                      267               224                435                        356               263               524                  80               340                        310                 138                  1029           275           1080                706                     567                425             1684           304                1048         232         1452          1014                    682                             382          32         56             19              188               814                    111         305                        399                         324                    605                550                 1279           94                222         218          153                566         197                     374           69         332                372                1251
# ...         ...                             ...             ...                    ...                 ...           ...                      ...               ...                ...                        ...               ...               ...                 ...               ...                        ...                 ...                   ...           ...            ...                ...                     ...                ...              ...           ...                 ...         ...          ...           ...                    ...                             ...         ...        ...            ...              ...               ...                    ...         ...                        ...                         ...                    ...                ...                  ...          ...                ...         ...          ...                ...         ...                     ...          ...         ...                ...                 ...
# 6063      29501                             285            1392                    335                 223          1297                      252               196                368                        299               312               477                  72               306                        282                 136                  1089           255            856                652                     541                373             1457           290                1082         293         1258           779                    732                             382          36         60             19              210               746                    103         259                        328                         262                    514                456                 1085           81                197         193          151                582         205                     321           75         381                413                1048
# 6064      29502                             262            1324                    301                 202          1204                      236               181                378                        294               287               468                  66               309                        311                 145                  1016           246            818                572                     464                375             1390           291                1016         269         1151           732                    647                             331          36         65             23              274               770                    101         245                        319                         261                    514                440                  985           81                196         183          160                570         186                     296           61         347                377                 974
# 6065      29503                             260            1334                    318                 213          1259                      234               183                363                        332               299               460                  70               317                        311                 139                  1063           262            846                637                     525                370             1412           285                1093         286         1166           793                    609                             326          39         62             18              204               739                     97         249                        338                         288                    530                459                 1050           82                192         191          144                559         190                     318           72         364                400                 986
Female   5-Apr-12  Camp Shelby  Army National Guard          Combat Support        42A                 Texas  Hispanic   51        67        180        Right hand
# 5765                    650         400          411                   433                483                             457                      58                      383                  130                359                    399                           1323          99              377                   237                   1051                  318             142            881                     794            525  1620     1613                 1316            1043                 616             157            721           422               131                  838                           1648              446           334                 971         243                      374                   958       717                 157          804  Female   5-Apr-12  Camp Shelby  Army National Guard          Combat Support        25U                 Texas  Hispanic   40        63        150        Right hand
# 5766                    640         400          412                   450                517                             476                      57                      412                  111                352                    402                           1318         116              392                   259                   1054                  338             136            841                     848            566  1740     1644                 1337            1054                 640             159            758           449               127                  862                           1590              444           335                 982         254                      351                   970       762                 159          774  Female   5-Apr-12  Camp Shelby  Army National Guard          Combat Support        42A                 Texas     Black   40        66        168        Right hand
# 5767                    640         383          418                   432                491                             445                      58                      400                  119                326                    380                           1286         111              375                   230                    996                  321             136            854                     791            530  1628     1616                 1288            1028                 623             163            725           419               135                  802                           1525              450           298                 837         208                      335                   952       632                 146          769  Female   5-Apr-12  Camp Shelby  Army National Guard          Combat Support        92Y                 Texas  Hispanic   31        63        133        Right hand
# 5768                    595         333          373                   444                504                             445                      66                      372                  114                325                    381                           1372         112              390                   249                    997                  339             135            861                     821            542  1685     1641                 1334            1089                 592             162            762           436               130                  849                           1547              462           299                 891         223                      394                   943       610                 154          797  Female  28-May-11   Fort McCoy  Army National Guard          Combat Support        92F                 Texas  Hispanic   27        66        132        Right hand
#
# [5769 rows x 106 columns]

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(), cmap ="coolwarm")
# Out:
# <AxesSubplot:>

# %%
df_temp = df.corr()

feature =[]
collinear=[]
for col in df_temp.columns:
    for i in df_temp.index:
        if (df_temp[col][i]> .9 and df_temp[col][i] < 1) or (df_temp[col][i]< -.9 and df_temp[col][i] > -1) :
                feature.append(col)
                collinear.append(i)

# %%
my_dict = {"feature":feature, "collinear":collinear}
df_col = pd.DataFrame(my_dict)
df_col
# Out:
#                             feature                       collinear
# 0    abdominalextensiondepthsitting              waistcircumference
# 1    abdominalextensiondepthsitting                      waistdepth
# 2                    acromialheight                    axillaheight
# 3                    acromialheight                 cervicaleheight
# 4                    acromialheight                     chestheight
# 5                    acromialheight              iliocristaleheight
# 6                    acromialheight               kneeheightsitting
# 7                    acromialheight                         stature
# 8                    acromialheight             suprasternaleheight
# 9                    acromialheight                  tenthribheight
# 10                   acromialheight            waistheightomphalion
# 11                   acromialheight                     wristheight
# 12                   acromialheight                        Heightin
# 13            acromionradialelength             shoulderelbowlength
# 14            acromionradialelength                   sleeveoutseam
# 15                     axillaheight                  acromialheight
# 16                     axillaheight                 cervicaleheight
# 17                     axillaheight                     chestheight
# 18                     axillaheight                    crotchheight
# 19                     axillaheight              iliocristaleheight
# 20                     axillaheight            kneeheightmidpatella
# 21                     axillaheight               kneeheightsitting
# 22                     axillaheight                 poplitealheight
# 23                     axillaheight                         stature
# 24                     axillaheight             suprasternaleheight
# 25                     axillaheight                  tenthribheight
# 26                     axillaheight                    tibialheight
# 27                     axillaheight            waistheightomphalion
# 28                     axillaheight                     wristheight
# 29                     axillaheight                        Heightin
# 30          balloffootcircumference           footbreadthhorizontal
# 31                 balloffootlength                      footlength
# 32                biacromialbreadth           shouldercircumference
# 33        bicepscircumferenceflexed      forearmcircumferenceflexed
# 34                 bideltoidbreadth           forearmforearmbreadth
# 35                 bideltoidbreadth           shouldercircumference
# 36                 bideltoidbreadth                        weightkg
# 37             buttockcircumference                      hipbreadth
# 38             buttockcircumference              thighcircumference
# 39                    buttockheight                    crotchheight
# 40                    buttockheight              iliocristaleheight
# 41                    buttockheight            kneeheightmidpatella
# 42                    buttockheight               kneeheightsitting
# 43                    buttockheight                  tenthribheight
# 44                    buttockheight                    tibialheight
# 45                    buttockheight             trochanterionheight
# 46                buttockkneelength          buttockpopliteallength
# 47           buttockpopliteallength               buttockkneelength
# 48                  cervicaleheight                  acromialheight
# 49                  cervicaleheight                    axillaheight
# 50                  cervicaleheight                     chestheight
# 51                  cervicaleheight                    crotchheight
# 52                  cervicaleheight             functionalleglength
# 53                  cervicaleheight              iliocristaleheight
# 54                  cervicaleheight            kneeheightmidpatella
# 55                  cervicaleheight               kneeheightsitting
# 56                  cervicaleheight                 poplitealheight
# 57                  cervicaleheight                            span
# 58                  cervicaleheight                         stature
# 59                  cervicaleheight             suprasternaleheight
# 60                  cervicaleheight                  tenthribheight
# 61                  cervicaleheight            waistheightomphalion
# 62                  cervicaleheight                        Heightin
# 63               chestcircumference                        weightkg
# 64                      chestheight                  acromialheight
# 65                      chestheight                    axillaheight
# 66                      chestheight                 cervicaleheight
# 67                      chestheight                    crotchheight
# 68                      chestheight              iliocristaleheight
# 69                      chestheight               kneeheightsitting
# 70                      chestheight                 poplitealheight
# 71                      chestheight                         stature
# 72                      chestheight             suprasternaleheight
# 73                      chestheight                  tenthribheight
# 74                      chestheight            waistheightomphalion
# 75                      chestheight                        Heightin
# 76                     crotchheight                    axillaheight
# 77                     crotchheight                   buttockheight
# 78                     crotchheight                 cervicaleheight
# 79                     crotchheight                     chestheight
# 80                     crotchheight              iliocristaleheight
# 81                     crotchheight            kneeheightmidpatella
# 82                     crotchheight               kneeheightsitting
# 83                     crotchheight  lateralfemoralepicondyleheight
# 84                     crotchheight                 poplitealheight
# 85                     crotchheight             suprasternaleheight
# 86                     crotchheight                  tenthribheight
# 87                     crotchheight                    tibialheight
# 88                     crotchheight             trochanterionheight
# 89                     crotchheight            waistheightomphalion
# 90                 eyeheightsitting                   sittingheight
# 91            footbreadthhorizontal         balloffootcircumference
# 92                       footlength                balloffootlength
# 93        forearmcenterofgriplength               forearmhandlength
# 94        forearmcenterofgriplength            radialestylionlength
# 95        forearmcenterofgriplength                            span
# 96       forearmcircumferenceflexed       bicepscircumferenceflexed
# 97            forearmforearmbreadth                bideltoidbreadth
# 98                forearmhandlength       forearmcenterofgriplength
# 99                forearmhandlength               kneeheightsitting
# 100               forearmhandlength            radialestylionlength
# 101               forearmhandlength                   sleeveoutseam
# 102               forearmhandlength                            span
# 103             functionalleglength                 cervicaleheight
# 104             functionalleglength               kneeheightsitting
# 105             functionalleglength             suprasternaleheight
# 106                     handbreadth               handcircumference
# 107               handcircumference                     handbreadth
# 108               handcircumference              wristcircumference
# 109                      hipbreadth            buttockcircumference
# 110                      hipbreadth               hipbreadthsitting
# 111               hipbreadthsitting                      hipbreadth
# 112              iliocristaleheight                  acromialheight
# 113              iliocristaleheight                    axillaheight
# 114              iliocristaleheight                   buttockheight
# 115              iliocristaleheight                 cervicaleheight
# 116              iliocristaleheight                     chestheight
# 117              iliocristaleheight                    crotchheight
# 118              iliocristaleheight            kneeheightmidpatella
# 119              iliocristaleheight               kneeheightsitting
# 120              iliocristaleheight                 poplitealheight
# 121              iliocristaleheight                         stature
# 122              iliocristaleheight             suprasternaleheight
# 123              iliocristaleheight                  tenthribheight
# 124              iliocristaleheight                    tibialheight
# 125              iliocristaleheight             trochanterionheight
# 126              iliocristaleheight            waistheightomphalion
# 127                      interscyei                     interscyeii
# 128                     interscyeii                      interscyei
# 129            kneeheightmidpatella                    axillaheight
# 130            kneeheightmidpatella                   buttockheight
# 131            kneeheightmidpatella                 cervicaleheight
# 132            kneeheightmidpatella                    crotchheight
# 133            kneeheightmidpatella              iliocristaleheight
# 134            kneeheightmidpatella               kneeheightsitting
# 135            kneeheightmidpatella  lateralfemoralepicondyleheight
# 136            kneeheightmidpatella                 poplitealheight
# 137            kneeheightmidpatella                  tenthribheight
# 138            kneeheightmidpatella                    tibialheight
# 139            kneeheightmidpatella             trochanterionheight
# 140            kneeheightmidpatella            waistheightomphalion
# 141               kneeheightsitting                  acromialheight
# 142               kneeheightsitting                    axillaheight
# 143               kneeheightsitting                   buttockheight
# 144               kneeheightsitting                 cervicaleheight
# 145               kneeheightsitting                     chestheight
# 146               kneeheightsitting                    crotchheight
# 147               kneeheightsitting               forearmhandlength
# 148               kneeheightsitting             functionalleglength
# 149               kneeheightsitting              iliocristaleheight
# 150               kneeheightsitting            kneeheightmidpatella
# 151               kneeheightsitting  lateralfemoralepicondyleheight
# 152               kneeheightsitting                 poplitealheight
# 153               kneeheightsitting                            span
# 154               kneeheightsitting                         stature
# 155               kneeheightsitting             suprasternaleheight
# 156               kneeheightsitting                  tenthribheight
# 157               kneeheightsitting                    tibialheight
# 158               kneeheightsitting             trochanterionheight
# 159               kneeheightsitting            waistheightomphalion
# 160  lateralfemoralepicondyleheight                    crotchheight
# 161  lateralfemoralepicondyleheight            kneeheightmidpatella
# 162  lateralfemoralepicondyleheight               kneeheightsitting
# 163  lateralfemoralepicondyleheight                 poplitealheight
# 164  lateralfemoralepicondyleheight                  tenthribheight
# 165  lateralfemoralepicondyleheight                    tibialheight
# 166  lateralfemoralepicondyleheight             trochanterionheight
# 167               neckcircumference           neckcircumferencebase
# 168           neckcircumferencebase               neckcircumference
# 169                 poplitealheight                    axillaheight
# 170                 poplitealheight                 cervicaleheight
# 171                 poplitealheight                     chestheight
# 172                 poplitealheight                    crotchheight
# 173                 poplitealheight              iliocristaleheight
# 174                 poplitealheight            kneeheightmidpatella
# 175                 poplitealheight               kneeheightsitting
# 176                 poplitealheight  lateralfemoralepicondyleheight
# 177                 poplitealheight                    tibialheight
# 178                 poplitealheight            waistheightomphalion
# 179            radialestylionlength       forearmcenterofgriplength
# 180            radialestylionlength               forearmhandlength
# 181            radialestylionlength                   sleeveoutseam
# 182            radialestylionlength                            span
# 183           shouldercircumference               biacromialbreadth
# 184           shouldercircumference                bideltoidbreadth
# 185             shoulderelbowlength           acromionradialelength
# 186             shoulderelbowlength                   sleeveoutseam
# 187             shoulderelbowlength                            span
# 188                   sittingheight                eyeheightsitting
# 189          sleevelengthspinewrist                   sleeveoutseam
# 190          sleevelengthspinewrist                            span
# 191                   sleeveoutseam           acromionradialelength
# 192                   sleeveoutseam               forearmhandlength
# 193                   sleeveoutseam            radialestylionlength
# 194                   sleeveoutseam             shoulderelbowlength
# 195                   sleeveoutseam          sleevelengthspinewrist
# 196                   sleeveoutseam                            span
# 197                            span                 cervicaleheight
# 198                            span       forearmcenterofgriplength
# 199                            span               forearmhandlength
# 200                            span               kneeheightsitting
# 201                            span            radialestylionlength
# 202                            span             shoulderelbowlength
# 203                            span          sleevelengthspinewrist
# 204                            span                   sleeveoutseam
# 205                            span             suprasternaleheight
# 206                         stature                  acromialheight
# 207                         stature                    axillaheight
# 208                         stature                 cervicaleheight
# 209                         stature                     chestheight
# 210                         stature              iliocristaleheight
# 211                         stature               kneeheightsitting
# 212                         stature             suprasternaleheight
# 213                         stature                  tenthribheight
# 214                         stature            waistheightomphalion
# 215                         stature                        Heightin
# 216             suprasternaleheight                  acromialheight
# 217             suprasternaleheight                    axillaheight
# 218             suprasternaleheight                 cervicaleheight
# 219             suprasternaleheight                     chestheight
# 220             suprasternaleheight                    crotchheight
# 221             suprasternaleheight             functionalleglength
# 222             suprasternaleheight              iliocristaleheight
# 223             suprasternaleheight               kneeheightsitting
# 224             suprasternaleheight                            span
# 225             suprasternaleheight                         stature
# 226             suprasternaleheight                  tenthribheight
# 227             suprasternaleheight            waistheightomphalion
# 228             suprasternaleheight                        Heightin
# 229                  tenthribheight                  acromialheight
# 230                  tenthribheight                    axillaheight
# 231                  tenthribheight                   buttockheight
# 232                  tenthribheight                 cervicaleheight
# 233                  tenthribheight                     chestheight
# 234                  tenthribheight                    crotchheight
# 235                  tenthribheight              iliocristaleheight
# 236                  tenthribheight            kneeheightmidpatella
# 237                  tenthribheight               kneeheightsitting
# 238                  tenthribheight  lateralfemoralepicondyleheight
# 239                  tenthribheight                         stature
# 240                  tenthribheight             suprasternaleheight
# 241                  tenthribheight                    tibialheight
# 242                  tenthribheight             trochanterionheight
# 243                  tenthribheight            waistheightomphalion
# 244              thighcircumference            buttockcircumference
# 245                    tibialheight                    axillaheight
# 246                    tibialheight                   buttockheight
# 247                    tibialheight                    crotchheight
# 248                    tibialheight              iliocristaleheight
# 249                    tibialheight            kneeheightmidpatella
# 250                    tibialheight               kneeheightsitting
# 251                    tibialheight  lateralfemoralepicondyleheight
# 252                    tibialheight                 poplitealheight
# 253                    tibialheight                  tenthribheight
# 254                    tibialheight             trochanterionheight
# 255                    tibialheight            waistheightomphalion
# 256             trochanterionheight                   buttockheight
# 257             trochanterionheight                    crotchheight
# 258             trochanterionheight              iliocristaleheight
# 259             trochanterionheight            kneeheightmidpatella
# 260             trochanterionheight               kneeheightsitting
# 261             trochanterionheight  lateralfemoralepicondyleheight
# 262             trochanterionheight                  tenthribheight
# 263             trochanterionheight                    tibialheight
# 264             trochanterionheight            waistheightomphalion
# 265   verticaltrunkcircumferenceusa                        weightkg
# 266                    waistbreadth              waistcircumference
# 267              waistcircumference  abdominalextensiondepthsitting
# 268              waistcircumference                    waistbreadth
# 269              waistcircumference                      waistdepth
# 270                      waistdepth  abdominalextensiondepthsitting
# 271                      waistdepth              waistcircumference
# 272            waistheightomphalion                  acromialheight
# 273            waistheightomphalion                    axillaheight
# 274            waistheightomphalion                 cervicaleheight
# 275            waistheightomphalion                     chestheight
# 276            waistheightomphalion                    crotchheight
# 277            waistheightomphalion              iliocristaleheight
# 278            waistheightomphalion            kneeheightmidpatella
# 279            waistheightomphalion               kneeheightsitting
# 280            waistheightomphalion                 poplitealheight
# 281            waistheightomphalion                         stature
# 282            waistheightomphalion             suprasternaleheight
# 283            waistheightomphalion                  tenthribheight
# 284            waistheightomphalion                    tibialheight
# 285            waistheightomphalion             trochanterionheight
# 286            waistheightomphalion                        Heightin
# 287                        weightkg                bideltoidbreadth
# 288                        weightkg              chestcircumference
# 289                        weightkg   verticaltrunkcircumferenceusa
# 290                        weightkg                       Weightlbs
# 291              wristcircumference               handcircumference
# 292                     wristheight                  acromialheight
# 293                     wristheight                    axillaheight
# 294                        Heightin                  acromialheight
# 295                        Heightin                    axillaheight
# 296                        Heightin                 cervicaleheight
# 297                        Heightin                     chestheight
# 298                        Heightin                         stature
# 299                        Heightin             suprasternaleheight
# 300                        Heightin            waistheightomphalion
# 301                       Weightlbs                        weightkg

# %%
df_temp = df.corr()
filteredDf = df_temp[((df_temp >= .9) | (df_temp <= -.9)) & (df_temp !=1.000)]
plt.figure(figsize=(20,10))
sns.heatmap(filteredDf,cmap="PiYG")  #, annot=True
plt.show()

# %%
df.corr().abs().unstack().sort_values(ascending=False).drop_duplicates()
# Out:
# subjectid               subjectid                         1.000000
# cervicaleheight         stature                           0.991053
# suprasternaleheight     stature                           0.989120
#                         cervicaleheight                   0.989112
# axillaheight            acromialheight                    0.987115
#                                                             ...
# shoulderlength          elbowrestheight                   0.001873
# elbowrestheight         lateralfemoralepicondyleheight    0.001434
# buttockheight           elbowrestheight                   0.000728
# subjectid               balloffootlength                  0.000510
# lateralmalleolusheight  hipbreadthsitting                 0.000236
# Length: 4657, dtype: float64

# %%
df_col.value_counts("feature")
# Out:
# feature
# kneeheightsitting                 19
# cervicaleheight                   15
# tenthribheight                    15
# waistheightomphalion              15
# axillaheight                      15
# iliocristaleheight                15
# crotchheight                      14
# suprasternaleheight               13
# chestheight                       12
# kneeheightmidpatella              12
# acromialheight                    11
# tibialheight                      11
# stature                           10
# poplitealheight                   10
# trochanterionheight                9
# span                               9
# Heightin                           7
# buttockheight                      7
# lateralfemoralepicondyleheight     7
# sleeveoutseam                      6
# forearmhandlength                  5
# radialestylionlength               4
# weightkg                           4
# functionalleglength                3
# bideltoidbreadth                   3
# forearmcenterofgriplength          3
# shoulderelbowlength                3
# waistcircumference                 3
# shouldercircumference              2
# waistdepth                         2
# sleevelengthspinewrist             2
# wristheight                        2
# hipbreadth                         2
# handcircumference                  2
# abdominalextensiondepthsitting     2
# acromionradialelength              2
# buttockcircumference               2
# interscyei                         1
# buttockkneelength                  1
# wristcircumference                 1
# balloffootcircumference            1
# balloffootlength                   1
# waistbreadth                       1
# verticaltrunkcircumferenceusa      1
# biacromialbreadth                  1
# bicepscircumferenceflexed          1
# thighcircumference                 1
# chestcircumference                 1
# buttockpopliteallength             1
# interscyeii                        1
# eyeheightsitting                   1
# footbreadthhorizontal              1
# sittingheight                      1
# footlength                         1
# forearmcircumferenceflexed         1
# forearmforearmbreadth              1
# handbreadth                        1
# neckcircumferencebase              1
# neckcircumference                  1
# Weightlbs                          1
# hipbreadthsitting                  1
# dtype: int64

# %%
def outlier_function(df, col_name,k):
    ''' this function detects first and third quartile and interquartile range for a given column of a dataframe
    then calculates upper and lower limits to determine outliers conservatively
    returns the number of lower and uper limit and number of outliers respectively
    '''
    first_quartile = np.percentile(np.array(df[col_name].tolist()), 25)
    third_quartile = np.percentile(np.array(df[col_name].tolist()), 75)
    IQR = third_quartile - first_quartile
                      
    upper_limit = third_quartile+(k*IQR)
    lower_limit = first_quartile-(k*IQR)
    outlier_count = 0
                      
    for value in df[col_name].tolist():
        if (value < lower_limit) | (value > upper_limit):
            outlier_count +=1
    return lower_limit, upper_limit, outlier_count

# %%
# loop through all columns to see if there are any outliers
k=1.5
print("\tNumber of Outliers for {}*IQR\n".format(k))
total=0
for col in df.select_dtypes("number"):
    if outlier_function(df.select_dtypes("number"), col,k)[2] > 0:
        outliers=outlier_function(df.select_dtypes("number"), col, k)[2]
        total+=outliers
        print("{} outliers in '{}'".format(outliers,col))
print("\n\t{} OUTLIERS TOTALLY".format(total))
# Out:
# 	Number of Outliers for 1.5*IQR
#
# 1 outliers in 'subjectid'
# 46 outliers in 'abdominalextensiondepthsitting'
# 14 outliers in 'acromialheight'
# 31 outliers in 'acromionradialelength'
# 73 outliers in 'anklecircumference'
# 27 outliers in 'axillaheight'
# 23 outliers in 'balloffootcircumference'
# 11 outliers in 'balloffootlength'
# 1 outliers in 'biacromialbreadth'
# 19 outliers in 'bicepscircumferenceflexed'
# 57 outliers in 'bicristalbreadth'
# 12 outliers in 'bideltoidbreadth'
# 6 outliers in 'bimalleolarbreadth'
# 46 outliers in 'bitragionchinarc'
# 16 outliers in 'bitragionsubmandibulararc'
# 6 outliers in 'bizygomaticbreadth'
# 58 outliers in 'buttockcircumference'
# 47 outliers in 'buttockdepth'
# 42 outliers in 'buttockheight'
# 27 outliers in 'buttockkneelength'
# 25 outliers in 'buttockpopliteallength'
# 53 outliers in 'calfcircumference'
# 10 outliers in 'cervicaleheight'
# 29 outliers in 'chestbreadth'
# 15 outliers in 'chestcircumference'
# 29 outliers in 'chestdepth'
# 11 outliers in 'chestheight'
# 19 outliers in 'crotchheight'
# 51 outliers in 'crotchlengthomphalion'
# 29 outliers in 'crotchlengthposterioromphalion'
# 53 outliers in 'earbreadth'
# 23 outliers in 'earlength'
# 45 outliers in 'earprotrusion'
# 39 outliers in 'elbowrestheight'
# 13 outliers in 'eyeheightsitting'
# 13 outliers in 'footbreadthhorizontal'
# 10 outliers in 'footlength'
# 16 outliers in 'forearmcenterofgriplength'
# 4 outliers in 'forearmcircumferenceflexed'
# 6 outliers in 'forearmforearmbreadth'
# 26 outliers in 'forearmhandlength'
# 23 outliers in 'functionalleglength'
# 50 outliers in 'handlength'
# 44 outliers in 'headbreadth'
# 39 outliers in 'headcircumference'
# 38 outliers in 'headlength'
# 7 outliers in 'heelanklecircumference'
# 44 outliers in 'heelbreadth'
# 79 outliers in 'hipbreadth'
# 73 outliers in 'hipbreadthsitting'
# 33 outliers in 'iliocristaleheight'
# 105 outliers in 'interpupillarybreadth'
# 11 outliers in 'interscyei'
# 8 outliers in 'interscyeii'
# 28 outliers in 'kneeheightmidpatella'
# 18 outliers in 'kneeheightsitting'
# 41 outliers in 'lateralfemoralepicondyleheight'
# 9 outliers in 'lateralmalleolusheight'
# 76 outliers in 'lowerthighcircumference'
# 18 outliers in 'mentonsellionlength'
# 4 outliers in 'neckcircumference'
# 1 outliers in 'neckcircumferencebase'
# 13 outliers in 'overheadfingertipreachsitting'
# 22 outliers in 'palmlength'
# 15 outliers in 'poplitealheight'
# 24 outliers in 'radialestylionlength'
# 1 outliers in 'shouldercircumference'
# 25 outliers in 'shoulderelbowlength'
# 27 outliers in 'shoulderlength'
# 10 outliers in 'sittingheight'
# 6 outliers in 'sleevelengthspinewrist'
# 16 outliers in 'sleeveoutseam'
# 20 outliers in 'span'
# 11 outliers in 'stature'
# 11 outliers in 'suprasternaleheight'
# 23 outliers in 'tenthribheight'
# 59 outliers in 'thighcircumference'
# 77 outliers in 'thighclearance'
# 26 outliers in 'thumbtipreach'
# 38 outliers in 'tibialheight'
# 38 outliers in 'tragiontopofhead'
# 40 outliers in 'trochanterionheight'
# 25 outliers in 'verticaltrunkcircumferenceusa'
# 18 outliers in 'waistbacklength'
# 26 outliers in 'waistbreadth'
# 28 outliers in 'waistcircumference'
# 53 outliers in 'waistdepth'
# 33 outliers in 'waistfrontlengthsitting'
# 19 outliers in 'waistheightomphalion'
# 54 outliers in 'weightkg'
# 5 outliers in 'wristcircumference'
# 22 outliers in 'wristheight'
# 21 outliers in 'Age'
# 27 outliers in 'Heightin'
# 46 outliers in 'Weightlbs'
#
# 	2710 OUTLIERS TOTALLY

# %%
sns.boxplot(df["wristheight"])
# Out:
# <AxesSubplot:xlabel='wristheight'>

# %%
k=3
for i in df.select_dtypes("number"):
    lower,upper,outliers=outlier_function(df.select_dtypes("number"),i,k)
    df=df[(df.select_dtypes("number")[i]>lower)&(df.select_dtypes("number")[i]<upper)]

# %%
df.shape
# Out:
# (5759, 106)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5759 entries, 0 to 5767
# Columns: 106 entries, subjectid to WritingPreference
# dtypes: int64(97), object(9)
# memory usage: 4.7+ MB

# %% [markdown]
# # DATA Preprocessing
# - In this step we divide our data to X(Features) and y(Target) then ,
# - To train and evaluation purposes we create train and test sets,
# - Lastly, scale our data if features not in same scale. Why?

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
X=pd.get_dummies(df.drop(columns=['DODRace']))
y = df['DODRace']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %%
scaler = StandardScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
print("Train features shape : ", X_train.shape)
print("Train target shape   : ", y_train.shape)
print("Test features shape  : ", X_test.shape)
print("Test target shape    : ", y_test.shape)
# Out:
# Train features shape :  (4607, 790)
# Train target shape   :  (4607,)
# Test features shape  :  (1152, 790)
# Test target shape    :  (1152,)

# %% [markdown]
# # Modelling
# - Fit the model with train dataset
# - Get predict from vanilla model on both train and test sets to examine if there is over/underfitting
# - Apply GridseachCV for both hyperparemeter tuning and sanity test of our model.
# - Use hyperparameters that you find from gridsearch and make final prediction and evaluate the result according to chosen metric.

# %% [markdown]
# ## 1. Logistic model

# %% [markdown]
# ### Vanilla Logistic Model

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.pipeline import Pipeline
operations = [("scaler", MinMaxScaler()), ("log", LogisticRegression(class_weight='balanced',max_iter=10000,random_state=101))]
pipe_log_model = Pipeline(steps=operations)

# %%
def eval_metric(model, X_train, y_train, X_test, y_test):
    y_train_pred = model.predict(X_train)
    y_pred = model.predict(X_test)
    print("Test_Set")
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    print()
    print("Train_Set")
    print(confusion_matrix(y_train, y_train_pred))
    print(classification_report(y_train, y_train_pred))

# %%
pipe_log_model.fit(X_train,y_train)
eval_metric(pipe_log_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[228  11  16]
#  [  9  96  21]
#  [ 15  71 685]]
#               precision    recall  f1-score   support
#
#        Black       0.90      0.89      0.90       255
#     Hispanic       0.54      0.76      0.63       126
#        White       0.95      0.89      0.92       771
#
#     accuracy                           0.88      1152
#    macro avg       0.80      0.85      0.82      1152
# weighted avg       0.89      0.88      0.88      1152
#
#
# Train_Set
# [[1006   14   18]
#  [  10  506   35]
#  [  48  261 2709]]
#               precision    recall  f1-score   support
#
#        Black       0.95      0.97      0.96      1038
#     Hispanic       0.65      0.92      0.76       551
#        White       0.98      0.90      0.94      3018
#
#     accuracy                           0.92      4607
#    macro avg       0.86      0.93      0.88      4607
# weighted avg       0.93      0.92      0.92      4607

# %%
scoring = {"f1_Hispanic" : make_scorer(f1_score, average = None, labels =["Hispanic"]),
           "precision_Hispanic" : make_scorer(precision_score, average = None, labels =["Hispanic"]),
           "recall_Hispanic" : make_scorer(recall_score, average = None, labels =["Hispanic"])}

# %%
operations = [("scaler", MinMaxScaler()), ("log", LogisticRegression(class_weight='balanced',max_iter=10000,random_state=101))]
model = Pipeline(steps=operations)

# %%
scores = cross_validate(model, X_train, y_train, scoring = scoring, cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_f1_Hispanic           0.604706
# test_precision_Hispanic    0.521319
# test_recall_Hispanic       0.724188
# dtype: float64

# %% [markdown]
# ### Logistic Model GridsearchCV

# %%
recall_Hispanic =  make_scorer(recall_score, average=None, labels=["Hispanic"])

# %%
param_grid = {
    "log__C": [0.1, 0.5, 1],
    'log__penalty': ["l1", "l2"],
    'log__solver': ['liblinear', 'lbfgs'],
}

# %%
operations = [("scaler", MinMaxScaler()), ("log", LogisticRegression(class_weight='balanced',max_iter=10000,random_state=101))]
model = Pipeline(steps=operations)

log_model_grid = GridSearchCV(model,
                              param_grid,
                              verbose=3,
                              scoring=recall_Hispanic,
                              n_jobs=-1, cv=5)

# %%
log_model_grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scaler', MinMaxScaler()),
#                                        ('log',
#                                         LogisticRegression(class_weight='balanced',
#                                                            max_iter=10000,
#                                                            random_state=101))]),
#              n_jobs=-1,
#              param_grid={'log__C': [0.1, 0.5, 1], 'log__penalty': ['l1', 'l2'],
#                          'log__solver': ['liblinear', 'lbfgs']},
#              scoring=make_scorer(recall_score, average=None, labels=['Hispanic']),
#              verbose=3)

# %%
log_model_grid.best_params_
# Out:
# {'log__C': 0.1, 'log__penalty': 'l2', 'log__solver': 'lbfgs'}

# %%
log_model_grid.best_score_
# Out:
# 0.7421785421785422

# %%
eval_metric(log_model_grid, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[229  10  16]
#  [  9 103  14]
#  [ 19  96 656]]
#               precision    recall  f1-score   support
#
#        Black       0.89      0.90      0.89       255
#     Hispanic       0.49      0.82      0.61       126
#        White       0.96      0.85      0.90       771
#
#     accuracy                           0.86      1152
#    macro avg       0.78      0.86      0.80      1152
# weighted avg       0.89      0.86      0.87      1152
#
#
# Train_Set
# [[ 965   30   43]
#  [  23  456   72]
#  [  67  351 2600]]
#               precision    recall  f1-score   support
#
#        Black       0.91      0.93      0.92      1038
#     Hispanic       0.54      0.83      0.66       551
#        White       0.96      0.86      0.91      3018
#
#     accuracy                           0.87      4607
#    macro avg       0.81      0.87      0.83      4607
# weighted avg       0.90      0.87      0.88      4607

# %%
from yellowbrick.classifier import PrecisionRecallCurve

operations = [("scaler", MinMaxScaler()), ("log", LogisticRegression(class_weight='balanced',max_iter=10000,random_state=101))]
model = Pipeline(steps=operations)

viz = PrecisionRecallCurve(
    model,
    per_class=True, classes= ["Black", "Hispanic", "White"],
    cmap="Set1"
)
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show();
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17320/1234434828.py in <module>
# ----> 1 from yellowbrick.classifier import PrecisionRecallCurve
#       2
#       3 operations = [("scaler", MinMaxScaler()), ("log", LogisticRegression(class_weight='balanced',max_iter=10000,random_state=101))]
#       4 model = Pipeline(steps=operations)
#       5
#
# ModuleNotFoundError: No module named 'yellowbrick'

# %%
viz.score_    #["Hispanic"]

# %%
y_pred = log_model_grid.predict(X_test)

log_AP = viz.score_["Hispanic"]
log_f1 = f1_score(y_test, y_pred, average=None, labels=["Hispanic"])
log_recall = recall_score(y_test, y_pred, average=None, labels=["Hispanic"])

# %% [markdown]
# ## 2. SVC

# %% [markdown]
# ### Vanilla SVC model

# %%
operations_svc = [("scaler", MinMaxScaler()), ("svc", SVC(class_weight="balanced",random_state=101))]
pipe_svc_model = Pipeline(steps=operations_svc)

# %%
pipe_svc_model.fit(X_train, y_train)

eval_metric(pipe_svc_model, X_train, y_train, X_test, y_test)

# %%
model = Pipeline(steps=operations_svc)

scores = cross_validate(model, X_train, y_train, scoring = scoring, cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]

# %% [markdown]
# ###  SVC Model GridsearchCV

# %%
param_grid = {
    'svc__C': [1,2,3],
    'svc__gamma': ["scale", "auto", 1, 0.1, 0.01]
}

# %%
operations_svc = [("scaler", MinMaxScaler()), ("svc", SVC(class_weight="balanced",random_state=101))]
model = Pipeline(steps=operations_svc)

svm_model_grid = GridSearchCV(model,
                              param_grid,
                              verbose=3,
                              scoring=recall_Hispanic,
                              n_jobs=-1)

# %%
svm_model_grid.fit(X_train, y_train)

# %%
svm_model_grid.best_params_

# %%
svm_model_grid.best_score_

# %%
eval_metric(svm_model_grid, X_train, y_train, X_test, y_test)

# %%
operations_svc = [("scaler", MinMaxScaler()), ("svc", SVC(C=2, class_weight="balanced",random_state=101))]
model = Pipeline(steps=operations_svc)

viz = PrecisionRecallCurve(
    model,
    per_class=True, classes= ["Black", "Hispanic", "White"],
    cmap="Set1"
)
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show();

# %%
y_pred = svm_model_grid.predict(X_test)

svc_AP = viz.score_["Hispanic"]
svc_f1 = f1_score(y_test, y_pred, average=None, labels=["Hispanic"])
svc_recall = recall_score(y_test, y_pred, average=None, labels=["Hispanic"])

# %% [markdown]
# ## 3. RF

# %% [markdown]
# ### Vanilla RF Model

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
X2 = df.drop("DODRace",axis=1)
y = df.DODRace

# %%
cat = X2.select_dtypes("object").columns
cat

# %%
enc = OrdinalEncoder()
X2[cat] = enc.fit_transform(X2[cat])
X2.head()

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y, test_size=0.2, random_state=101, stratify =y)

# %%
print("Train features shape : ", X_train2.shape)
print("Train target shape   : ", y_train2.shape)
print("Test features shape  : ", X_test2.shape)
print("Test target shape    : ", y_test2.shape)

# %%
rf_model = RandomForestClassifier(class_weight="balanced", random_state=101)

# %%
rf_model.fit(X_train2, y_train2)

# %%
eval_metric(rf_model, X_train2, y_train2, X_test2, y_test2)

# %%
model = RandomForestClassifier(class_weight="balanced", random_state=101)

scores = cross_validate(model, X_train2, y_train2, scoring = scoring, cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]

# %% [markdown]
# ### RF Model GridsearchCV

# %%
param_grid = {'n_estimators':[30,100,200],
             'criterion': ["gini","entropy"],
             'max_depth':[5,13,16],
             'min_samples_split':[2,6,10],
             }

# %%
rf_model = RandomForestClassifier()
rf_grid_model = GridSearchCV(rf_model,
                             param_grid,
                             verbose=2,
                             scoring="accuracy",
                             n_jobs=-1)

rf_grid_model.fit(X_train2,y_train2)

# %%
model = RandomForestClassifier(class_weight="balanced", random_state=101)

scores = cross_validate(model, X_train2, y_train2, scoring = scoring, cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]

# %%
rf_grid_model.best_score_

# %%
rf_grid_model.best_params_

# %%
eval_metric(rf_grid_model, X_train2, y_train2, X_test2, y_test2)

# %%
model = RandomForestClassifier(class_weight="balanced", random_state=101, max_depth=10, n_estimators = 500)

viz = PrecisionRecallCurve(
    model,
    per_class=True, classes= ["Black", "Hispanic", "White"],
    cmap="Set1"
)
viz.fit(X_train2, y_train2)
viz.score(X_test2, y_test2)
viz.show();

# %%
y_pred = rf_grid_model.predict(X_test2)

rf_AP = viz.score_["Hispanic"]
rf_f1 = f1_score(y_test2, y_pred, average=None, labels=["Hispanic"])
rf_recall = recall_score(y_test2, y_pred, average=None, labels=["Hispanic"])

# %% [markdown]
# ## 4. XGBoost

# %% [markdown]
# ### Vanilla XGBoost Model

# %%
xgb_classifier = XGBClassifier()
xgb_classifier.fit(X_train , y_train)

# %%
y_pred_test = xgb_classifier.predict(X_test)
y_pred_train = xgb_classifier.predict(X_train)

# %%
print("TEST REPORT")
print(classification_report(y_test, y_pred_test))
plot_confusion_matrix(xgb_classifier, X_test, y_test);

print("\n"*3, "-*"*30)
print("TRAIN REPORT")
print(classification_report(y_train, y_pred_train))
plot_confusion_matrix(xgb_classifier, X_train, y_train);

# %%
visualizer = ClassPredictionError(xgb_classifier)

# Fit the training data to the visualizer
visualizer.fit(X_train, y_train)

# Evaluate the model on the test data
visualizer.score(X_test, y_test)

# Draw visualization
visualizer.show()

# %%
rf_grid_model.best_score_

# %%
eval_metric(rf_grid_model, X_train2, y_train2, X_test2, y_test2)

# %% [markdown]
# ### XGBoost Model GridsearchCV

# %% [markdown]
# ---
# ---

# %% [markdown]
# ---
# ---

# %% [markdown]
# # SMOTE
# https://machinelearningmastery.com/smote-oversampling-for-imbalanced-classification/

# %% [markdown]
# ##  Smote implement

# %%
#pip install imblearn

# %%
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline

# %% [markdown]
# ## SVC Over/Under Sampling

# %% [markdown]
# ## Xgboost Over/ Under Sampling

# %% [markdown]
# - Evaluation metrics
# https://towardsdatascience.com/comprehensive-guide-on-multiclass-classification-metrics-af94cfb83fbd

# %%
from sklearn.metrics import matthews_corrcoef

matthews_corrcoef(y_test, y_pred)

# %%
from sklearn.metrics import cohen_kappa_score

cohen_kappa_score(y_test, y_pred)

# %% [markdown]
# #  SHAP
#
# https://towardsdatascience.com/shap-explain-any-machine-learning-model-in-python-24207127cad7

# %%
#pip install shap

# %%
import shap
explainer = shap.Explainer(log_model,X_train)
start_index = 203
end_index = 204
shap_values = explainer.shap_values(X_test[start_index:end_index])

# %%
shap_values

# %%
print(shap_values[0].shape)

# %%
# %% >> Visualize local predictions
shap.initjs()
# Force plot
prediction = log_model.predict(X_test[start_index:end_index])[0]
print(f"The log_model predicted: {prediction}")
shap.force_plot(explainer.expected_value[1],
                shap_values[1],
                X_test[start_index:end_index], # for values
                feature_names= X.columns,)

# %%
shap.summary_plot(shap_values, X_train,max_display=300,feature_names = X.columns)

# %% [markdown]
# # Before the Deployment
# - Choose the model that works best based on your chosen metric
# - For final step, fit the best model with whole dataset to get better performance.
# - And your model ready to deploy, dump your model and scaler.

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
